# %% [markdown]
# # Testing psutils for the sys stats module

# %%
import psutil

# CPU: Must contian usag , percore, frequency

cpu_usage = psutil.cpu_percent(interval=1)
print(f"CPU_Usage: {cpu_usage}")

cpu_per_core = psutil.cpu_percent(interval=1, percpu=True)
print(f"Per_Core: {cpu_per_core}")

cpu_freq = psutil.cpu_freq()
print(f"Freq: {cpu_freq}")

ram_total = psutil.virtual_memory()
ram_used = psutil.virtual_memory()

print(ram_total[0]  / (1024 * 1024 * 1024))

print(ram_total)
# Out:
# CPU_Usage: 8.0
# Per_Core: [31.4, 10.8, 20.3, 13.8, 21.9, 9.4, 17.2, 12.5]
# Freq: scpufreq(current=2496.0, min=0.0, max=2496.0)
# 7.650856018066406
# svmem(total=8215044096, available=1107775488, percent=86.5, used=7107268608, free=1107775488)
