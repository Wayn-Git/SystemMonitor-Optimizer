# %% [markdown]
# # Testing psutils for the sys stats module

# %%
import sys

sys.executable
# Out:
# '/home/wayne/Github/SystemMonitor-Optimizer/.venv/bin/python'

# %%
import psutil

# CPU: Must contian usag , percore, frequency

cpu_usage = psutil.cpu_percent(interval=1)
print(f"CPU_Usage: {cpu_usage}")

cpu_per_core = psutil.cpu_percent(interval=1, percpu=True)
print(f"Per_Core: {cpu_per_core}")

cpu_freq = psutil.cpu_freq()
print(f"Freq: {cpu_freq}")

ram_total = psutil.virtual_memory()
ram_used = psutil.virtual_memory()

print(ram_total[0]  / (1024 * 1024 * 1024))

print(ram_total)

current_part = psutil.disk_partitions()
disk_usage = psutil.disk_usage(path=True)

print(disk_usage)
# Out:
# CPU_Usage: 22.1
# Per_Core: [19.2, 22.2, 24.5, 22.4, 24.8, 28.0, 21.2, 30.3]
# Freq: scpufreq(current=4068.9802499999996, min=400.0, max=4500.0)
# 7.401985168457031
# svmem(total=7947821056, available=1401294848, percent=82.4, used=6546526208, free=351383552, active=3628232704, inactive=2643787776, buffers=51740672, cached=2508951552, shared=1043558400, slab=294531072)
# sdiskusage(total=0, used=0, free=0, percent=0.0)
# /home/wayne/Github/SystemMonitor-Optimizer/.venv/lib/python3.13/site-packages/psutil/_psposix.py:164: RuntimeWarning: bool is used as a file descriptor
#   st = os.statvfs(path)
